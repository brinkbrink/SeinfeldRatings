# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seinfeld_full = pd.read_csv('SeinfeldData.csv')

# %%
pd.set_option('display.max_rows', None)
seinfeld_full.head(170)
# Out:
#      Season                    Title       Airdate  Rating  Vote_count  \
# 0         1      Good News, Bad News   5 Jul. 1989     7.6        3431
# 1         1             The Stakeout   31 May 1990     7.7        2749
# 2         1              The Robbery   7 Jun. 1990     7.6        2496
# 3         1           Male Unbonding  14 Jun. 1990     7.4        2465
# 4         1            The Stock Tip  21 Jun. 1990     7.5        2352
# 5         2        The Ex-Girlfriend  23 Jan. 1991     7.7        2261
# 6         2          The Pony Remark  30 Jan. 1991     7.9        2351
# 7         2               The Jacket   6 Feb. 1991     8.4        2298
# 8         2        The Phone Message  13 Feb. 1991     8.4        2296
# 9         2            The Apartment   4 Apr. 1991     7.9        2076
# 10        2               The Statue  11 Apr. 1991     8.1        2089
# 11        2              The Revenge  18 Apr. 1991     8.3        2114
# ...

# %%
seinfeld_full.columns
# Out:
# Index(['Season', 'Title', 'Airdate', 'Rating', 'Vote_count', 'Description'], dtype='object')

# %%
seinfeld_full['Episode'] = seinfeld_full.groupby('Season').cumcount() + 1

# %%
seinfeld_full.head(20)
# Out:
#     Season                   Title       Airdate  Rating  Vote_count  \
# 0        1     Good News, Bad News   5 Jul. 1989     7.6        3431
# 1        1            The Stakeout   31 May 1990     7.7        2749
# 2        1             The Robbery   7 Jun. 1990     7.6        2496
# 3        1          Male Unbonding  14 Jun. 1990     7.4        2465
# 4        1           The Stock Tip  21 Jun. 1990     7.5        2352
# 5        2       The Ex-Girlfriend  23 Jan. 1991     7.7        2261
# 6        2         The Pony Remark  30 Jan. 1991     7.9        2351
# 7        2              The Jacket   6 Feb. 1991     8.4        2298
# 8        2       The Phone Message  13 Feb. 1991     8.4        2296
# 9        2           The Apartment   4 Apr. 1991     7.9        2076
# 10       2              The Statue  11 Apr. 1991     8.1        2089
# 11       2             The Revenge  18 Apr. 1991     8.3        2114
# 12       2        The Heart Attack  25 Apr. 1991     7.9        2096
# ...

# %%
seinfeld_rating = seinfeld_full.loc[:, ['Season', 'Episode', 'Rating']]

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(heatmap_data, cmap='magma', linewidths=0.30, annot=True)
plt.xlabel('Season')
plt.ylabel('Episode')
plt.title('Heatmap of Ratings by Episode and Season')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(heatmap_data, cmap='rocket', linewidths=0.30, annot=True)
plt.xlabel('Season')
plt.ylabel('Episode')
plt.title('Heatmap of Ratings by Episode and Season')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(heatmap_data, cmap='viridis', linewidths=0.30, annot=True)
plt.xlabel('Season')
plt.ylabel('Episode')
plt.title('Heatmap of Ratings by Episode and Season')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(heatmap_data, cmap='icefire', linewidths=0.30, annot=True)
plt.xlabel('Season')
plt.ylabel('Episode')
plt.title('Heatmap of Ratings by Episode and Season')
plt.show()
